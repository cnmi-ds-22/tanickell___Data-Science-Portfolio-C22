# %% [markdown]
# # Lists

# %% [markdown]
# ## Creating lists

# %% [markdown]
# Create a list of numbers with at least 10 numbers and give it a good name

# %% [markdown]
# Create a list of mixed types (integers, floats, strings, lists, etc.)and give it a good name

# %% [markdown]
# ## Indexing and Slicing

# %% [markdown]
# Access the second item in your mixed types list

# %% [markdown]
# Access the 4th-7th items in your list of numbers

# %% [markdown]
# Access the last 4 items in your mixed types list

# %% [markdown]
# ## Exploring

# %%
# @title Python list methods ( from W3Schools )
import pandas as pd

pd.read_html( "https://www.w3schools.com/python/python_ref_list.asp" )[0].style.hide(axis='index')
# Out:
# <style type="text/css">
# </style>
# <table id="T_d3ce0" class="dataframe">
#   <thead>
#     <tr>
#       <th id="T_d3ce0_level0_col0" class="col_heading level0 col0" >Method</th>
#       <th id="T_d3ce0_level0_col1" class="col_heading level0 col1" >Description</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_d3ce0_row0_col0" class="data row0 col0" >append()</td>
#       <td id="T_d3ce0_row0_col1" class="data row0 col1" >Adds an element at the end of the list</td>
#     </tr>
#     <tr>
#       <td id="T_d3ce0_row1_col0" class="data row1 col0" >clear()</td>
#       <td id="T_d3ce0_row1_col1" class="data row1 col1" >Removes all the elements from the list</td>
#     </tr>
#     <tr>
#       <td id="T_d3ce0_row2_col0" class="data row2 col0" >copy()</td>
#       <td id="T_d3ce0_row2_col1" class="data row2 col1" >Returns a copy of the list</td>
#     </tr>
#     <tr>
#       <td id="T_d3ce0_row3_col0" class="data row3 col0" >count()</td>
# ...

# %% [markdown]
# Find some list methods that we have not covered in class and try a few out.  You can use the built-in help features to learn what they do.  For more information, you can explore the on-line [documentation]( https://docs.python.org/3.11/library/stdtypes.html#sequence-types-list-tuple-range )

# %%
# list method on numbers list

# %%
# list method on mixed type list
